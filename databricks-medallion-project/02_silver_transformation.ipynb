# %%
df = spark.read.format("csv") \
    .option("header", True) \
    .load("/Volumes/raw/sales.csv")

df.write.format("delta") \
    .mode("append") \
    .saveAsTable("enterprise_lakehouse.bronze.sales")
